# %%
import pandas as pd
import json

# %%
with open('Out_put.json') as f:
    data = json.load(f)

# %%
len(data)
# Out:
# 107

# %%
df_format = pd.DataFrame(data)
df_format.head()
# Out:
#                                             Filename  Positive Score  \
# 0  httpsinsights.blackcoffer.comai-healthcare-rev...              85
# 1  httpsinsights.blackcoffer.comai-human-robotics...              34
# 2  httpsinsights.blackcoffer.comai-in-healthcare-...              72
# 3  httpsinsights.blackcoffer.comai-tool-alexa-goo...              21
# 4  httpsinsights.blackcoffer.comall-you-need-to-k...              52
#
#    Negative Score  Polarity Score  Subjectivity Score  Avg Sentence Length  \
# 0              29       20.361288           87.798777               1815.0
# 1              13        7.114610           31.615368               1236.0
# 2              27       17.287528           67.280254               1798.0
# 3               5        4.996364           19.002879                512.0
# 4              10       16.628615           36.763160                963.0
#
#    Percentage of Complex Words   FOG Index  Avg Number of Words per Sentence  \
# ...

# %%
df_format = df_format.rename(columns={'Filename': 'URL'})
df_format
# Out:
#                                                    URL  Positive Score  \
# 0    httpsinsights.blackcoffer.comai-healthcare-rev...              85
# 1    httpsinsights.blackcoffer.comai-human-robotics...              34
# 2    httpsinsights.blackcoffer.comai-in-healthcare-...              72
# 3    httpsinsights.blackcoffer.comai-tool-alexa-goo...              21
# 4    httpsinsights.blackcoffer.comall-you-need-to-k...              52
# ..                                                 ...             ...
# 102  httpsinsights.blackcoffer.comwill-ai-replace-u...              63
# 103  httpsinsights.blackcoffer.comwill-machine-repl...              79
# 104  httpsinsights.blackcoffer.comwill-technology-e...              30
# 105  httpsinsights.blackcoffer.comwill-we-ever-colo...              61
# 106  httpsinsights.blackcoffer.comwill-we-ever-unde...              69
#
#      Negative Score  Polarity Score  Subjectivity Score  Avg Sentence Length  \
# ...

# %%
df_format = df_format.rename(columns=str.upper)
df_format.head()
# Out:
#                                                  URL  POSITIVE SCORE  \
# 0  httpsinsights.blackcoffer.comai-healthcare-rev...              85
# 1  httpsinsights.blackcoffer.comai-human-robotics...              34
# 2  httpsinsights.blackcoffer.comai-in-healthcare-...              72
# 3  httpsinsights.blackcoffer.comai-tool-alexa-goo...              21
# 4  httpsinsights.blackcoffer.comall-you-need-to-k...              52
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0              29       20.361288           87.798777               1815.0
# 1              13        7.114610           31.615368               1236.0
# 2              27       17.287528           67.280254               1798.0
# 3               5        4.996364           19.002879                512.0
# 4              10       16.628615           36.763160                963.0
#
#    PERCENTAGE OF COMPLEX WORDS   FOG INDEX  AVG NUMBER OF WORDS PER SENTENCE  \
# ...

# %%
df_format.insert(0, 'URL_ID', df_format.reset_index().index + 1)

# %%
df_format.head()
# Out:
#    URL_ID                                                URL  POSITIVE SCORE  \
# 0       1  httpsinsights.blackcoffer.comai-healthcare-rev...              85
# 1       2  httpsinsights.blackcoffer.comai-human-robotics...              34
# 2       3  httpsinsights.blackcoffer.comai-in-healthcare-...              72
# 3       4  httpsinsights.blackcoffer.comai-tool-alexa-goo...              21
# 4       5  httpsinsights.blackcoffer.comall-you-need-to-k...              52
#
#    NEGATIVE SCORE  POLARITY SCORE  SUBJECTIVITY SCORE  AVG SENTENCE LENGTH  \
# 0              29       20.361288           87.798777               1815.0
# 1              13        7.114610           31.615368               1236.0
# 2              27       17.287528           67.280254               1798.0
# 3               5        4.996364           19.002879                512.0
# 4              10       16.628615           36.763160                963.0
#
# ...

# %%
df_modified = df_format

# %%
df_format = df_modified

# %%
df_format.to_excel('Output_Data_Structure.xlsx', index=False)
